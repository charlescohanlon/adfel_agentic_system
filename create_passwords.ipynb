# %%
# Create unique strong passwords for each user in the DB file
import pandas as pd
from app import DB_FILE

df = pd.read_excel(DB_FILE)

# %%
import secrets
import string


def generate_password(length=16):
    """Generate a strong alphanumeric password."""
    alphabet = string.ascii_letters + string.digits
    return "".join(secrets.choice(alphabet) for _ in range(length))

# %%
generate_password()
# Out:
# 'dmLsDq9QNcCZLT5o'

# %%
# Generate unique passwords for each row
df["password"] = [generate_password() for _ in range(len(df))]

# Save to the same Excel file
df.to_excel(DB_FILE, index=False)

# %%
# Reset usage and limits for all users
import pandas as pd
from app import DB_FILE

# Read the DB file
df = pd.read_excel(DB_FILE)

# Add token usage columns
df['token_usage_limit'] = 1000000
df['token_usage'] = 0

# Save to the same Excel file
df.to_excel(DB_FILE, index=False)
